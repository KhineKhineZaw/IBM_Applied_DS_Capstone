# %% [markdown]
# # To Open a Korean Restaurant

# %% [markdown]
# ## Khine Khine Zaw (www.github.com/KhineKhineZaw)

# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# #### 1.1 Background

# %% [markdown]
# For this Applied Data Science Capstone Project, I would like to open a Korean Restaurant in Toronto area.
# As Korean food is very popular among Asians, I choose Korean restaurant.
# In this project, I am going to find the most suitable location to open Korean Restaurant.

# %% [markdown]
# #### 1.2 Business Problem
# The main problem in opening a restaurant is to find a location. For this problem, I am going to use machine learning and data science to solve the problem.

# %% [markdown]
# #### 1.3Target Audience

# %% [markdown]
# For enterpreneur who would like to open Korean Restaurant in Toronto area.

# %% [markdown]
# ### 2. Data

# %% [markdown]
# List of neighborhoods in Toronto, Canada,
# Latitude and Longitude of these neighborhoods,
# List of Asian restaurants data
